# %% [markdown]
# # Survey Analysis - Interested Parties Group (INT)
#
# This notebook analyzes all INT-group questions based on:
# - cleaned responses: `survey_responses_submitted_cleaned.csv`
# - question metadata: `survey_questions_en.csv`
# - subquestion metadata: `survey_question_subquestions_en.csv`
#
# Design:
# - one section per question
# - tables first, then visualizations
# - beginner-friendly code comments

# %% [markdown]
# ## 1) Imports and shared notebook helpers

# %%
import sys
from pathlib import Path

# Ensure repository root is on sys.path so `notebooks.*` imports always resolve.
repo_root = Path.cwd().resolve()
if repo_root.name == 'notebooks':
    repo_root = repo_root.parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from notebooks.survey_notebook_utils import (
    load_group_context,
    run_group_question_sequence,
    setup_notebook_style,
    show_group_overview,
)

setup_notebook_style()

# %% [markdown]
# ## 2) Group configuration

# %%
# Keep this list explicit so the analysis order is easy to explain.
GROUP_CODE = 'INT'
QUESTION_CODES = [
    'INTbond',
    'INTopinion',
    'INTknow',
    'INTvisit',
    'INTtech',
    'INTknowtyp',
    'INTwho',
    'INTfin',
    'INTgood',
]

# %% [markdown]
# ## 3) Load inputs and show overview

# %%
# Load data and show one compact overview table block.
ctx = load_group_context(GROUP_CODE)
show_group_overview(ctx)
# Out:
# Responses loaded: ../survey_responses_submitted_cleaned.csv -> (88, 281)
# Questions loaded: ../survey_questions_en.csv -> (45, 12)
# Subquestions loaded: ../survey_question_subquestions_en.csv -> (176, 7)
# INT respondents: 37
#
# Question catalog for this group:
#    question_order question_code question_type  \
# 0              34       INTbond             M
# 1              35    INTopinion             T
# 2              36       INTknow             1
# 3              37      INTvisit             M
# 4              38       INTtech             5
# 5              39    INTknowtyp             F
# 6              40        INTwho             M
# 7              41        INTfin             5
# 8              42       INTgood             T
#
#                                                                                                                                                                                                             question_text  \
# 0                                                                                                                                                                                       Do you have a bond to a teenager?
# 1                         What's your opinion on teenagers learning more about agriculture and how to grow food? ( Is there more they could take away than factual knowledge? e.g. values, responsibility, social skills)
# 2  What do you think is important for teenagers aged 13-19 to learn, compared to what the target group would actually find interesting? (1 being least interesting or important to 5 being most interesting or important)
# 3                                                                                                                                                                       I would visit an agricultural exhibition if it...
# 4                                                                                                                How do you feel about the use of digital technologies in exhibitions? (1-very negative, 5-very positive)
# 5                                                                                                                               Which sort of knowledge do you find important? (1-not important at all, 5-very important)
# 6                                                                                                                                                    When you think about a horticultural exhibition, who would visit it?
# 7                                                                                                To what extent do you think the budget constraints the quality of exhibitions for teenagers? (1-not at all, 5-very much)
# 8                                                What has your personal experience with a "good exhibition" within any topic been? (What was the topic?, Where did it take place?, Do you remember what got you engaged?)
#
#    n_subquestions
# 0               6
# 1               0
# 2              15
# 3              11
# 4               0
# 5               5
# 6               6
# 7               0
# 8               0
# Availability check (parsed questions vs cleaned columns):
#   question_code question_type  n_cols_in_cleaned     status  \
# 0       INTbond             M                  7  available
# 1    INTopinion             T                  1  available
# 2       INTknow             1                 30  available
# 3      INTvisit             M                 12  available
# 4       INTtech             5                  1  available
# 5    INTknowtyp             F                  5  available
# 6        INTwho             M                  7  available
# 7        INTfin             5                  1  available
# 8       INTgood             T                  1  available
#
#                                                                                                                       columns
# 0                                      INTbond[1], INTbond[2], INTbond[3], INTbond[4], INTbond[5], INTbond[6], INTbond[other]
# 1                                                                                                                  INTopinion
# 2  INTknow[1][1], INTknow[1][2], INTknow[2][1], INTknow[2][2], INTknow[3][1], INTknow[3][2], INTknow[4][1], INTknow[4][2] ...
# 3                  INTvisit[1], INTvisit[2], INTvisit[3], INTvisit[4], INTvisit[5], INTvisit[6], INTvisit[7], INTvisit[8] ...
# 4                                                                                                                     INTtech
# 5                                                   INTknowtyp[1], INTknowtyp[2], INTknowtyp[3], INTknowtyp[4], INTknowtyp[5]
# 6                                             INTwho[1], INTwho[2], INTwho[3], INTwho[4], INTwho[5], INTwho[6], INTwho[other]
# 7                                                                                                                      INTfin
# 8                                                                                                                     INTgood
# All parsed group questions are available in the cleaned dataset.

# %% [markdown]
# ## 4) Run full question analysis

# %%
# Run all group questions in the order defined above.
# `analyze_group_question` prints question title/text + tables/plots for each question.
run_group_question_sequence(ctx, QUESTION_CODES)
# Out:
# ### 34) INTbond (type `M`)
# Do you have a bond to a teenager?
#             item  n_selected  pct_selected
# 5             No          12          32.4
# 3         Friend           9          24.3
# 0         Parent           5          13.5
# 1        Sibling           4          10.8
# 2   Grand parent           1           2.7
# 4  Tutor/Teacher           0           0.0
# Other free-text answers:
# Non-empty answers: 7 / 37 (18.9%)
# <style type="text/css">
# #T_4bc84 table {
#   table-layout: fixed;
#   width: 100%;
# }
# #T_4bc84 th {
#   text-align: left;
# }
# #T_4bc84 td {
#   vertical-align: top;
# }
# #T_4bc84_row0_col0, #T_4bc84_row1_col0, #T_4bc84_row2_col0, #T_4bc84_row3_col0, #T_4bc84_row4_col0, #T_4bc84_row5_col0, #T_4bc84_row6_col0 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_4bc84">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4bc84_level0_col0" class="col_heading level0 col0" >response</th>
#       <th id="T_4bc84_level0_col1" class="col_heading level0 col1" >n_chars</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4bc84_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4bc84_row0_col0" class="data row0 col0" >Cousins/ relatives</td>
#       <td id="T_4bc84_row0_col1" class="data row0 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_4bc84_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4bc84_row1_col0" class="data row1 col0" >Familie</td>
#       <td id="T_4bc84_row1_col1" class="data row1 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_4bc84_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4bc84_row2_col0" class="data row2 col0" >ich arbeite ehrenamtlich mit Jugendlichen</td>
#       <td id="T_4bc84_row2_col1" class="data row2 col1" >41</td>
#     </tr>
#     <tr>
#       <th id="T_4bc84_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4bc84_row3_col0" class="data row3 col0" >Family in general, youth work</td>
#       <td id="T_4bc84_row3_col1" class="data row3 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_4bc84_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4bc84_row4_col0" class="data row4 col0" >Nephews</td>
#       <td id="T_4bc84_row4_col1" class="data row4 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_4bc84_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4bc84_row5_col0" class="data row5 col0" >Patentante von 3 Jugendlichen; pädagogische und therapeutische Begleitung für Kinder Kinder & Jugendliche</td>
#       <td id="T_4bc84_row5_col1" class="data row5 col1" >105</td>
#     </tr>
#     <tr>
#       <th id="T_4bc84_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4bc84_row6_col0" class="data row6 col0" >Step parent</td>
#       <td id="T_4bc84_row6_col1" class="data row6 col1" >11</td>
#     </tr>
#   </tbody>
# </table>
# ### 35) INTopinion (type `T`)
# What's your opinion on teenagers learning more about agriculture and how to grow food? ( Is there more they could take away than factual knowledge? e.g. values, responsibility, social skills)
# Non-empty answers: 29 / 37 (78.4%)
# <style type="text/css">
# #T_b57dc table {
#   table-layout: fixed;
#   width: 100%;
# }
# #T_b57dc th {
#   text-align: left;
# }
# #T_b57dc td {
#   vertical-align: top;
# }
# #T_b57dc_row0_col1, #T_b57dc_row1_col1, #T_b57dc_row2_col1, #T_b57dc_row3_col1, #T_b57dc_row4_col1, #T_b57dc_row5_col1, #T_b57dc_row6_col1, #T_b57dc_row7_col1, #T_b57dc_row8_col1, #T_b57dc_row9_col1, #T_b57dc_row10_col1, #T_b57dc_row11_col1, #T_b57dc_row12_col1, #T_b57dc_row13_col1, #T_b57dc_row14_col1, #T_b57dc_row15_col1, #T_b57dc_row16_col1, #T_b57dc_row17_col1, #T_b57dc_row18_col1, #T_b57dc_row19_col1, #T_b57dc_row20_col1, #T_b57dc_row21_col1, #T_b57dc_row22_col1, #T_b57dc_row23_col1, #T_b57dc_row24_col1, #T_b57dc_row25_col1, #T_b57dc_row26_col1, #T_b57dc_row27_col1, #T_b57dc_row28_col1 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_b57dc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b57dc_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_b57dc_level0_col1" class="col_heading level0 col1" >response</th>
#       <th id="T_b57dc_level0_col2" class="col_heading level0 col2" >n_chars</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b57dc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b57dc_row0_col0" class="data row0 col0" >18</td>
#       <td id="T_b57dc_row0_col1" class="data row0 col1" >Mehr über den Nahrungsanbau zu wissen, kann nur hilfreich sein für die Wertschätzung untereinander und der Natur gegenüber. Gemeinsame Aufenthalte in landwirtschaftlichen Bereichen haben mir in der Schulzeit viel Spaß gemacht und mir alternative Perspektiven zum Aufwachsen in der Stadt gegeben.</td>
#       <td id="T_b57dc_row0_col2" class="data row0 col2" >295</td>
#     </tr>
#     <tr>
#       <th id="T_b57dc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b57dc_row1_col0" class="data row1 col0" >22</td>
#       <td id="T_b57dc_row1_col1" class="data row1 col1" >I think it's very important, especially for teens living in cities, whose lives are very separated from agriculture. I think many kids are unaware of where food comes from and how food is grown</td>
#       <td id="T_b57dc_row1_col2" class="data row1 col2" >193</td>
#     </tr>
#     <tr>
#       <th id="T_b57dc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b57dc_row2_col0" class="data row2 col0" >25</td>
#       <td id="T_b57dc_row2_col1" class="data row2 col1" >Very important skill to learn to respect the planet we all live in and to learn that nutrition comes from agriculture effort and that is a hard work to make all agricultural consumables grow and flourish.</td>
#       <td id="T_b57dc_row2_col2" class="data row2 col2" >204</td>
#     </tr>
#     <tr>
#       <th id="T_b57dc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b57dc_row3_col0" class="data row3 col0" >28</td>
#       <td id="T_b57dc_row3_col1" class="data row3 col1" >Absolut. Thematik wird unterschätzt. Geht ja auch ums Ökosystem einerseits anderseits auch um die Gesundheit</td>
#       <td id="T_b57dc_row3_col2" class="data row3 col2" >108</td>
#     </tr>
#     <tr>
#       <th id="T_b57dc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b57dc_row4_col0" class="data row4 col0" >29</td>
#       <td id="T_b57dc_row4_col1" class="data row4 col1" >Ich denke es ist sehr wichtig Wissen in diesem Bereich zu vermitteln, um die Jugendlichen in Hinblick auf Klimakrise und die zukünftigen Herausforderungen der Landwirtschaft zu sensibilisieren. Ich empfinde eine Kombination aus der Vermittlung von Fachwissen und aber auch praktischen Einblicken in die Landwirtschaft und deren unterschiedlichen Herangehensweisen sehr wichtig. Landwirtschaft und den Anbau von Lebensmitteln stellt einen zentralen Pfeiler unserer Lebensgrundlage da und um dies langfristig zu sichern ist es wichtig Wissen und Werte zu vermitteln.</td>
#       <td id="T_b57dc_row4_col2" class="data row4 col2" >564</td>
#     </tr>
#     <tr>
#       <th id="T_b57dc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b57dc_row5_col0" class="data row5 col0" >44</td>
#       <td id="T_b57dc_row5_col1" class="data row5 col1" >Give them practical knowledge instead of books</td>
#       <td id="T_b57dc_row5_col2" class="data row5 col2" >46</td>
#     </tr>
#     <tr>
#       <th id="T_b57dc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b57dc_row6_col0" class="data row6 col0" >45</td>
#       <td id="T_b57dc_row6_col1" class="data row6 col1" >I support it! It would be cool for them to learn that there are more sustainable means to grow their food. And also cultivates ownership.</td>
#       <td id="T_b57dc_row6_col2" class="data row6 col2" >137</td>
#     </tr>
#     <tr>
#       <th id="T_b57dc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b57dc_row7_col0" class="data row7 col0" >48</td>
#       <td id="T_b57dc_row7_col1" class="data row7 col1" >Ich finde es wichtig, dass Jugendliche über den Ursprung von Lebensmitteln informiert werden.</td>
#       <td id="T_b57dc_row7_col2" class="data row7 col2" >93</td>
#     </tr>
#     <tr>
#       <th id="T_b57dc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b57dc_row8_col0" class="data row8 col0" >52</td>
#       <td id="T_b57dc_row8_col1" class="data row8 col1" >It important in order to gain knowledge</td>
#       <td id="T_b57dc_row8_col2" class="data row8 col2" >39</td>
#     </tr>
#     <tr>
#       <th id="T_b57dc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b57dc_row9_col0" class="data row9 col0" >53</td>
#       <td id="T_b57dc_row9_col1" class="data row9 col1" >i thinks its valuable knowledge. i had gardening class in school, which involed a 1m² of land and learning about plants and how to cook certain stuff. very good enrichment for kids. i think learning about agriculture and food, can lead to more informed decisions in each age group and is not necessarly thought in school or at home</td>
#       <td id="T_b57dc_row9_col2" class="data row9 col2" >331</td>
#     </tr>
#     <tr>
#       <th id="T_b57dc_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b57dc_row10_col0" class="data row10 col0" >69</td>
#       <td id="T_b57dc_row10_col1" class="data row10 col1" >Sustainability Responsibility</td>
#       <td id="T_b57dc_row10_col2" class="data row10 col2" >29</td>
#     </tr>
#     <tr>
#       <th id="T_b57dc_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b57dc_row11_col0" class="data row11 col0" >74</td>
#       <td id="T_b57dc_row11_col1" class="data row11 col1" >Es wäre gut und sinnvoll, wenn Jugendliche mehr über Landwirtschaft, wo Lebensmittel herkommen und welche Ressourcen dahinterstehen lernen würden. Dann könnten Entscheidungen bzgl. Ernährung bewusster getroffwn werden.</td>
#       <td id="T_b57dc_row11_col2" class="data row11 col2" >218</td>
#     </tr>
#     <tr>
#       <th id="T_b57dc_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b57dc_row12_col0" class="data row12 col0" >75</td>
#       <td id="T_b57dc_row12_col1" class="data row12 col1" >They may learn to respect and enjoy wholesome foods. Perhaps an understanding of agriculture helps inform their decisions to purchase responsibily sourced goods and support local initiatives.</td>
#       <td id="T_b57dc_row12_col2" class="data row12 col2" >191</td>
#     </tr>
#     <tr>
#       <th id="T_b57dc_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b57dc_row13_col0" class="data row13 col0" >82</td>
#       <td id="T_b57dc_row13_col1" class="data row13 col1" >Ich denke junge Menschen können auf jeden Fall mehr als Fakten lernen, wenn sie sich damit beschäftigen, wo Essen her kommt. Ich denke vor allem an Umweltbewusstsein und an ein Gefühl dafür, wie relevant es ist Umweltfreundlich zu leben. Damit geht sicher auch einher, das sie dies befähigt informiertere Entscheidungen in Bezug auf ihre eigene Ernährung treffen zu können.</td>
#       <td id="T_b57dc_row13
# ### 36) INTknow (type `1`)
# What do you think is important for teenagers aged 13-19 to learn, compared to what the target group would actually find interesting? (1 being least interesting or important to 5 being most interesting or important)
#                                           topic            scale_label  \
# 0           Biodiversity, insects & pollinators    Important for teens
# 1           Biodiversity, insects & pollinators  Interesting for teens
# 2                  Climate change & agriculture    Important for teens
# 3                  Climate change & agriculture  Interesting for teens
# 4            Food waste, storage & preservation    Important for teens
# 5            Food waste, storage & preservation  Interesting for teens
# 6                      Heavy machinery & motors    Important for teens
# 7                      Heavy machinery & motors  Interesting for teens
# 8   Job profiles & areas of work in agriculture    Important for teens
# 9   Job profiles & areas of work in agriculture  Interesting for teens
# 10                   Permaculture & Agroecology    Important for teens
# 11                   Permaculture & Agroecology  Interesting for teens
# 12        Pesticides & alternatives (pros/cons)    Important for teens
# 13        Pesticides & alternatives (pros/cons)  Interesting for teens
# 14        Plant nutrition (fertilizer, compost)    Important for teens
# 15        Plant nutrition (fertilizer, compost)  Interesting for teens
# 16             Soil and what makes it “healthy”    Important for teens
# 17             Soil and what makes it “healthy”  Interesting for teens
# 18     Strengths & weaknesses of regional crops    Important for teens
# 19     Strengths & weaknesses of regional crops  Interesting for teens
# 20                Sustainability in agriculture    Important for teens
# 21                Sustainability in agriculture  Interesting for teens
# 22  Technology in farming (sensors, drones, AI)    Important for teens
# 23  Technology in farming (sensors, drones, AI)  Interesting for teens
# 24       Urban gardening & growing food at home    Important for teens
# 25       Urban gardening & growing food at home  Interesting for teens
# 26        Water use and saving water in farming    Important for teens
# 27        Water use and saving water in farming  Interesting for teens
# 28        Where food comes from (farm to plate)    Important for teens
# 29        Where food comes from (farm to plate)  Interesting for teens
#
#     n_answered  mean  median
# 0           33  4.33     5.0
# 1           30  3.00     3.0
# 2           34  4.56     5.0
# 3           30  3.53     4.0
# 4           35  4.31     5.0
# 5           31  2.87     3.0
# 6           31  2.58     2.0
# 7           29  3.31     4.0
# 8           32  4.03     4.0
# 9           30  2.83     3.0
# 10          30  3.80     4.0
# 11          27  2.59     3.0
# 12          34  4.03     4.0
# 13          30  2.77     3.0
# 14          34  3.59     3.5
# 15          29  2.52     2.0
# 16          35  3.97     4.0
# 17          31  2.29     2.0
# 18          34  3.88     4.0
# 19          30  2.50     3.0
# 20          34  4.32     5.0
# 21          30  3.07     3.0
# 22          31  3.48     3.0
# 23          29  3.90     4.0
# 24          34  4.12     4.0
# 25          32  3.34     3.5
# 26          35  4.17     4.0
# 27          31  2.71     3.0
# 28          35  4.43     5.0
# 29          31  2.97     3.0
# scale_label                                        topic  \
# 0                  Where food comes from (farm to plate)
# 1                       Soil and what makes it “healthy”
# 2                  Water use and saving water in farming
# 3                           Climate change & agriculture
# 4                          Sustainability in agriculture
# 5                             Permaculture & Agroecology
# 6               Strengths & weaknesses of regional crops
# 7                    Biodiversity, insects & pollinators
# 8                  Pesticides & alternatives (pros/cons)
# 9                  Plant nutrition (fertilizer, compost)
# 10                    Food waste, storage & preservation
# 11           Technology in farming (sensors, drones, AI)
# 12                              Heavy machinery & motors
# 13                Urban gardening & growing food at home
# 14           Job profiles & areas of work in agriculture
#
# scale_label  mean_important_for_teens  mean_interesting_for_teens  \
# 0                                4.43                        2.97
# 1                                3.97                        2.29
# 2                                4.17                        2.71
# 3                                4.56                        3.53
# 4                                4.32                        3.07
# 5                                3.80                        2.59
# 6                                3.88                        2.50
# 7                                4.33                        3.00
# 8                                4.03                        2.77
# 9                                3.59                        2.52
# 10                               4.31                        2.87
# 11                               3.48                        3.90
# 12                               2.58                        3.31
# 13                               4.12                        3.34
# 14                               4.03                        2.83
#
# scale_label  difference_scale1_minus_scale2  combined_index  alignment_gap_abs
# 0                                      1.46            3.70               1.46
# 1                                      1.68            3.13               1.68
# 2                                      1.46            3.44               1.46
# 3                                      1.03            4.04               1.03
# 4                                      1.25            3.70               1.25
# 5                                      1.21            3.20               1.21
# 6                                      1.38            3.19               1.38
# 7                                      1.33            3.66               1.33
# 8                                      1.26            3.40               1.26
# 9                                      1.07            3.06               1.07
# 10                                     1.44            3.59               1.44
# 11                                    -0.42            3.69               0.42
# 12                                    -0.73            2.94               0.73
# 13                                     0.78            3.73               0.78
# 14                                     1.20            3.43               1.20
# Difference interpretation (`Important for teens - Interesting for teens`): **green = calm** (more Important for teens than Interesting for teens, less urgent action), **pink = potential** (more Interesting for teens than Important for teens, opportunity for targeted support), values near 0 indicate a balanced profile.
# ### 37) INTvisit (type `M`)
# I would visit an agricultural exhibition if it...
#                                                             item  n_selected  \
# 3                                                 is informative          30
# 9                                      teaches critical thinking          30
# 2                                       is suitable for everyone          27
# 4                                  includes interactive elements          27
# 8                                       relates to everyday life          25
# 10                                     teaches factual knowledge          25
# 5                                      focuses on sustainability          21
# 7   focuses on mental health aspects too (Horticultural therapy)          13
# 0                                   is suitable for young people           9
# 1                                       is suitable for families           8
# 6                         prioritises teenager's wants and needs           4
#
#     pct_selected
# 3           81.1
# 9           81.1
# 2           73.0
# 4           73.0
# 8           67.6
# 10          67.6
# 5           56.8
# 7           35.1
# 0           24.3
# 1           21.6
# 6           10.8
# Other free-text answers:
# Non-empty answers: 4 / 37 (10.8%)
# <style type="text/css">
# #T_10f01 table {
#   table-layout: fixed;
#   width: 100%;
# }
# #T_10f01 th {
#   text-align: left;
# }
# #T_10f01 td {
#   vertical-align: top;
# }
# #T_10f01_row0_col0, #T_10f01_row1_col0, #T_10f01_row2_col0, #T_10f01_row3_col0 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_10f01">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10f01_level0_col0" class="col_heading level0 col0" >response</th>
#       <th id="T_10f01_level0_col1" class="col_heading level0 col1" >n_chars</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10f01_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_10f01_row0_col0" class="data row0 col0" >has good takeaways (also in form of a online magazine, flyers or something)</td>
#       <td id="T_10f01_row0_col1" class="data row0 col1" >75</td>
#     </tr>
#     <tr>
#       <th id="T_10f01_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_10f01_row1_col0" class="data row1 col0" >Is visually pleasing</td>
#       <td id="T_10f01_row1_col1" class="data row1 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_10f01_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_10f01_row2_col0" class="data row2 col0" >shows food supply chain in some way</td>
#       <td id="T_10f01_row2_col1" class="data row2 col1" >35</td>
#     </tr>
#     <tr>
#       <th id="T_10f01_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_10f01_row3_col0" class="data row3 col0" >mediale Fehlinterpretationen berichtigt.</td>
#       <td id="T_10f01_row3_col1" class="data row3 col1" >40</td>
#     </tr>
#   </tbody>
# </table>
# ### 38) INTtech (type `5`)
# How do you feel about the use of digital technologies in exhibitions? (1-very negative, 5-very positive)
#                 answer   n   pct
# 0                    1   0   0.0
# 1                    2   0   0.0
# 2                    3   5  13.5
# 3                    4  11  29.7
# 4                    5  16  43.2
# 5  Missing/Unspecified   5  13.5
# ### 39) INTknowtyp (type `F`)
# Which sort of knowledge do you find important? (1-not important at all, 5-very important)
# Item summary:
#                                                               item  \
# 0                                              practical knowledge
# 3                                                critical thinking
# 1  knowledge of your surroundings (Biology, Physics, Chemistry...)
# 2                                                 network thinking
# 4                                   broad knowledge of many things
#
#    n_answered  missing_pct  median  iqr  mean
# 0          36          2.7     5.0  1.0  4.39
# 3          36          2.7     5.0  1.0  4.56
# 1          36          2.7     4.0  2.0  3.81
# 2          35          5.4     4.0  1.0  3.69
# 4          34          8.1     4.0  2.0  3.94
# ### 40) INTwho (type `M`)
# When you think about a horticultural exhibition, who would visit it?
#                                                                          item  \
# 1                                  Primarily schools on project days or weeks
# 0                                                           I myself would go
# 3                            Grandparents with their grandchildren (families)
# 2                                                 Parents with their children
# 4                                           Groups of teenagers by themselves
# 5  As I don't really visit exhibitions, I don't envision or know the audience
#
#    n_selected  pct_selected
# 1          28          75.7
# 0          25          67.6
# 3          23          62.2
# 2          22          59.5
# 4           2           5.4
# 5           2           5.4
# Other free-text answers:
# Non-empty answers: 2 / 37 (5.4%)
# <style type="text/css">
# #T_52b76 table {
#   table-layout: fixed;
#   width: 100%;
# }
# #T_52b76 th {
#   text-align: left;
# }
# #T_52b76 td {
#   vertical-align: top;
# }
# #T_52b76_row0_col0, #T_52b76_row1_col0 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_52b76">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52b76_level0_col0" class="col_heading level0 col0" >response</th>
#       <th id="T_52b76_level0_col1" class="col_heading level0 col1" >n_chars</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52b76_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_52b76_row0_col0" class="data row0 col0" >Who’s interested in this field</td>
#       <td id="T_52b76_row0_col1" class="data row0 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_52b76_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_52b76_row1_col0" class="data row1 col0" >allgem. Interessierte z.B.: gesundheitlich Eingeschränkte (Allergiker*innen), techn. Interessierte, gesamtheitlich Denkende usw.</td>
#       <td id="T_52b76_row1_col1" class="data row1 col1" >128</td>
#     </tr>
#   </tbody>
# </table>
# ### 41) INTfin (type `5`)
# To what extent do you think the budget constraints the quality of exhibitions for teenagers? (1-not at all, 5-very much)
#                 answer   n   pct
# 0                    1   1   2.7
# 1                    2   1   2.7
# 2                    3   9  24.3
# 3                    4   7  18.9
# 4                    5  14  37.8
# 5  Missing/Unspecified   5  13.5
# ### 42) INTgood (type `T`)
# What has your personal experience with a "good exhibition" within any topic been? (What was the topic?, Where did it take place?, Do you remember what got you engaged?)
# Non-empty answers: 24 / 37 (64.9%)
# <style type="text/css">
# #T_c01de table {
#   table-layout: fixed;
#   width: 100%;
# }
# #T_c01de th {
#   text-align: left;
# }
# #T_c01de td {
#   vertical-align: top;
# }
# #T_c01de_row0_col1, #T_c01de_row1_col1, #T_c01de_row2_col1, #T_c01de_row3_col1, #T_c01de_row4_col1, #T_c01de_row5_col1, #T_c01de_row6_col1, #T_c01de_row7_col1, #T_c01de_row8_col1, #T_c01de_row9_col1, #T_c01de_row10_col1, #T_c01de_row11_col1, #T_c01de_row12_col1, #T_c01de_row13_col1, #T_c01de_row14_col1, #T_c01de_row15_col1, #T_c01de_row16_col1, #T_c01de_row17_col1, #T_c01de_row18_col1, #T_c01de_row19_col1, #T_c01de_row20_col1, #T_c01de_row21_col1, #T_c01de_row22_col1, #T_c01de_row23_col1 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_c01de">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c01de_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_c01de_level0_col1" class="col_heading level0 col1" >response</th>
#       <th id="T_c01de_level0_col2" class="col_heading level0 col2" >n_chars</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c01de_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c01de_row0_col0" class="data row0 col0" >18</td>
#       <td id="T_c01de_row0_col1" class="data row0 col1" >Barfußpfade, Sachen mit allen Sinnen erkunden, Kurzfilme, Augmented Reality</td>
#       <td id="T_c01de_row0_col2" class="data row0 col2" >75</td>
#     </tr>
#     <tr>
#       <th id="T_c01de_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c01de_row1_col0" class="data row1 col0" >22</td>
#       <td id="T_c01de_row1_col1" class="data row1 col1" >I think the most important part of a museum or exhibition is storytelling. Regardless of the topic, I find myself most engaged with an exhibition if the storytelling is compelling. It helps me to understand and it encourages dialogue/ questions / interactions</td>
#       <td id="T_c01de_row1_col2" class="data row1 col2" >259</td>
#     </tr>
#     <tr>
#       <th id="T_c01de_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c01de_row2_col0" class="data row2 col0" >28</td>
#       <td id="T_c01de_row2_col1" class="data row2 col1" >Interaktiv</td>
#       <td id="T_c01de_row2_col2" class="data row2 col2" >10</td>
#     </tr>
#     <tr>
#       <th id="T_c01de_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c01de_row3_col0" class="data row3 col0" >29</td>
#       <td id="T_c01de_row3_col1" class="data row3 col1" >Ansprache von unterschiedlichen Sinnen (Hören, Riechen, Tasten), Interaktive Elemente und kritische Fragen die eine Entscheidung erfordern und dann am Ende der Ausstellung werden die Fragen ausgewertet,</td>
#       <td id="T_c01de_row3_col2" class="data row3 col2" >202</td>
#     </tr>
#     <tr>
#       <th id="T_c01de_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c01de_row4_col0" class="data row4 col0" >44</td>
#       <td id="T_c01de_row4_col1" class="data row4 col1" >Sustainable technology and future gardening</td>
#       <td id="T_c01de_row4_col2" class="data row4 col2" >43</td>
#     </tr>
#     <tr>
#       <th id="T_c01de_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c01de_row5_col0" class="data row5 col0" >45</td>
#       <td id="T_c01de_row5_col1" class="data row5 col1" >It was in Bolzano about apples. The topic was about application of digital agriculture for precise use of inputs in an apple orchard in Canada</td>
#       <td id="T_c01de_row5_col2" class="data row5 col2" >142</td>
#     </tr>
#     <tr>
#       <th id="T_c01de_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c01de_row6_col0" class="data row6 col0" >53</td>
#       <td id="T_c01de_row6_col1" class="data row6 col1" >- interactive - takeaways (seeds, gadgets, flyers) - easy gain of knowledge, but also in depth facts, if your interested in something - i enjoy most if its wo a weekend or week, but comes back yearly with updates (kinda like Grüne Woche, except I dont enjoy that to much, but from the concept)</td>
#       <td id="T_c01de_row6_col2" class="data row6 col2" >293</td>
#     </tr>
#     <tr>
#       <th id="T_c01de_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c01de_row7_col0" class="data row7 col0" >55</td>
#       <td id="T_c01de_row7_col1" class="data row7 col1" >I do not visit exhibitions very often, but in my experience, interactive learning methods are always the most powerful for everybody. I always learn with interactiveness in museums and exhibitions.</td>
#       <td id="T_c01de_row7_col2" class="data row7 col2" >197</td>
#     </tr>
#     <tr>
#       <th id="T_c01de_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c01de_row8_col0" class="data row8 col0" >69</td>
#       <td id="T_c01de_row8_col1" class="data row8 col1" >Vivid presentation if the topic Practical examples Interactive elements</td>
#       <td id="T_c01de_row8_col2" class="data row8 col2" >71</td>
#     </tr>
#     <tr>
#       <th id="T_c01de_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c01de_row9_col0" class="data row9 col0" >74</td>
#       <td id="T_c01de_row9_col1" class="data row9 col1" >Ich finde es immer gut, wenn der Kontext von Ausstellungsstücken erklärt wird, aber die Ausstellung nicht zu textlastig ist.</td>
#       <td id="T_c01de_row9_col2" class="data row9 col2" >124</td>
#     </tr>
#     <tr>
#       <th id="T_c01de_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c01de_row10_col0" class="data row10 col0" >75</td>
#       <td id="T_c01de_row10_col1" class="data row10 col1" >A good exhibition is curated such that it has a story and flow that is easy to follow and digest. Multiple interactive modalities of communication is helpful. Video, audio etc etc.</td>
#       <td id="T_c01de_row10_col2" class="data row10 col2" >180</td>
#     </tr>
#     <tr>
#       <th id="T_c01de_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c01de_row11_col0" class="data row11 col0" >78</td>
#       <td id="T_c01de_row11_col1" class="data row11 col1" >Dass sie alle Bereiche der Landwirtschaft zeigt: Eine gute Mischung aus Maschinen und Technik, landwirtschaftlichen Produkten, Entwicklung des Berufs und jeweils Informationsangebote ohne aufdringlich zu sein</td>
#       <td id="T_c01de_row11_col2" class="data row11 col2" >208</td>
#     </tr>
#     <tr>
#       <th id="T_c01de_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c01de_row12_col0" class="data row12 col0" >82</td>
#       <td id="T_c01de_row12_col1" class="data row12 col1" >Das Porzellanmuseum in der Leuchtenburg bei Kahla (Thüringen) ist ein sehr schönes Museum. Es zeigt anschaulich, interaktiv und nicht zu komplex, wie Porzellan hergestellt wird. Die Ausstellung ist ästhetisch sehr schön eingerichtet und nutzt verschiedene Medien, um eine Stimmung zu erzeugen, in die man eintauchen kann (Musik, Ausstattung, (digitale) interaktive Spiele, anfassbare Ausstellungsstücke).</td>
#       <td id="T_c01de_row12_col2" class="data row12 col2" >404</td>
#     </tr>
#     <tr>
#       <th id="T_c01de_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c01de_row13_col0" class="data row13 col0" >84</td>
#       <td id="T_c01de_row13_col1" class="data row13 col1" >Interaktivität, verschiedene Materialien- Fotos, Film, etwas zum Erfassen (im Sinn des Wortes), Räumlichkeit (im Sinn von reingegehen). Geräusche? Eigentlich ist es gut, wenn mehr oder weniger alle Sinne angesprochen werden.</td>
#       <td id="T_c01de_row13_col2" class="data row13 col2" >224</td>
#     </tr>
#     <tr>
#       <th id="T_c01de_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c01de_row14_col0" class="data row14 col0" >86</td>
#       <td id="T_c01de_row14_col1" class="data row14 col1" >Deutsches Hygiene Museum has a lot of interesting exhibitions with many different types of media, interactive elements and different approaches to a specific topic that make it so many different people get engaged.</td>
#       <td
